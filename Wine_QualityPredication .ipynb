# %% [markdown]
# ### Approaching Ensemble technique of bagging

# %%
## importing the required library

import pandas as pd 
import numpy as np
from  sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score , confusion_matrix , roc_curve ,roc_auc_score
from pandas_profiling import ProfileReport

# %%
## Importing the data and reading the first 5 rows

df=pd.read_csv("C:/Users/Pc/Downloads/ml/machine learning/Decision Tree/Decision tree/winequality_red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
## model building 

from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
## Divinding the data into X and Y

x=df.drop(columns='quality')
y=df['quality']

# %%
## Dividing the dataset for training and testing 

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
## fitting the dataset for knn model
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
## Checking the accuracy score for training data

knn.score(x_train,y_train)
# Out:
# 0.6489444878811571

# %%
## Checking the accuracy score for testing data

knn.score(x_test,y_test)
# Out:
# 0.5

# %%
## Hyperparameter tunning for knn model

param_grid={'algorithm':['ball_tree','kd_tree','brute'],
            'leaf_size':[10,12,35,68,23,45,15],
            'n_neighbors':[3,5,8,9,10,12,13,15,20,30]
            
    
}

# %%
## applying GridSearchCV method to find the best parameter

grid=GridSearchCV(knn,param_grid,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3; total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3; total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3; total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3; total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=3; total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=5; total time=   0.0s
# [CV 2/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=5; total time=   0.0s
# [CV 3/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=5; total time=   0.0s
# [CV 4/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=5; total time=   0.0s
# [CV 5/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=5; total time=   0.0s
# [CV 1/5] END algorithm=ball_tree, leaf_size=10, n_neighbors=8; total time=   0.0s
# ...

# %%
## getting best parameter for knn model 

grid.best_params_
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 20}

# %%
knn1=KNeighborsClassifier(algorithm='ball_tree', leaf_size=10, n_neighbors= 20)

# %%
knn1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=10, n_neighbors=20)

# %%
knn1.score(x_train,y_train)
# Out:
# 0.5887412040656763

# %%
knn1.score(x_test,y_test)
# Out:
# 0.5

# %% [markdown]
# ## Building KNN model by using bagging technique ,finding the accuracy score to compare the score between KNN model and Bagging approach KNN model

# %%
bag_knn=BaggingClassifier(KNeighborsClassifier(algorithm='ball_tree', leaf_size=10, n_neighbors= 30),n_estimators=500)

# %%
bag_knn.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(algorithm='ball_tree',
#                                                       leaf_size=10,
#                                                       n_neighbors=30),
#                   n_estimators=500)

# %%
bag_knn.score(x_train,y_train)
# Out:
# 0.5731039874902267

# %%
bag_knn.score(x_test,y_test)
# Out:
# 0.509375
